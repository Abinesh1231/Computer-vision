# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinesh1231/Computer-vision/blob/main/cvactivity1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/medical_sample_dataset.zip -d /content/
# Out:
# unzip:  cannot find or open /content/medical_sample_dataset.zip, /content/medical_sample_dataset.zip.zip or /content/medical_sample_dataset.zip.ZIP.

# %%
import os

print("Folders inside /content:")
print(os.listdir("/content"))

print("\nImages folder:")
print(os.listdir("/content/images")[:5])

print("\nMasks folder:")
print(os.listdir("/content/masks")[:5])
# Out:
# Folders inside /content:
# ['.config', 'drive', 'images', 'medical_sample_dataset.zip', 'masks', 'sample_data']
#
# Images folder:
# ['img_5.png', 'img_14.png', 'img_3.png', 'img_4.png', 'img_1.png']
#
# Masks folder:
# ['img_5.png', 'img_14.png', 'img_3.png', 'img_4.png', 'img_1.png']

# %%
X, Y = load_data("/content/images",
                 "/content/masks")

print("Images shape:", X.shape)
print("Masks shape:", Y.shape)
# Out:
# Images shape: (20, 128, 128, 1)
# Masks shape: (20, 128, 128, 1)

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("/content/images/img_0.png", 0)
mask = cv2.imread("/content/masks/img_0.png", 0)

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.title("Image")
plt.imshow(img, cmap='gray')

plt.subplot(1,2,2)
plt.title("Mask")
plt.imshow(mask, cmap='gray')

plt.show()
